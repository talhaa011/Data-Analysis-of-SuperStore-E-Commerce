# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
t1 = pd.read_excel("Superstore.xlsx")
t1.head()
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   18606  Not Specified      0.01        2.88           0.50            2
# 1   20847           High      0.01        2.84           0.93            3
# 2   23086  Not Specified      0.03        6.68           6.15            3
# 3   23087  Not Specified      0.01        5.68           3.60            3
# 4   23088  Not Specified      0.00      205.99           2.50            3
#
#      Customer Name    Ship Mode Customer Segment Product Category  ...  \
# 0  Janice Fletcher  Regular Air        Corporate  Office Supplies  ...
# 1    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
# 2    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
# 3    Bonnie Potter  Regular Air        Corporate  Office Supplies  ...
# 4    Bonnie Potter  Express Air        Corporate       Technology  ...
#
#     Region State or Province       City  Postal Code Order Date  Ship Date  \
# ...

# %%
    t1.shape
# Out:
# (9426, 24)

# %%
t1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9426 entries, 0 to 9425
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Row ID                9426 non-null   int64
#  1   Order Priority        9426 non-null   object
#  2   Discount              9426 non-null   float64
#  3   Unit Price            9426 non-null   float64
#  4   Shipping Cost         9426 non-null   float64
#  5   Customer ID           9426 non-null   int64
#  6   Customer Name         9426 non-null   object
#  7   Ship Mode             9426 non-null   object
#  8   Customer Segment      9426 non-null   object
#  9   Product Category      9426 non-null   object
#  10  Product Sub-Category  9426 non-null   object
#  11  Product Container     9426 non-null   object
#  12  Product Name          9426 non-null   object
#  13  Product Base Margin   9354 non-null   float64
#  14  Region                9426 non-null   object
# ...

# %%
t1.isnull().sum()
# Out:
# Row ID                   0
# Order Priority           0
# Discount                 0
# Unit Price               0
# Shipping Cost            0
# Customer ID              0
# Customer Name            0
# Ship Mode                0
# Customer Segment         0
# Product Category         0
# Product Sub-Category     0
# Product Container        0
# Product Name             0
# Product Base Margin     72
# Region                   0
# State or Province        0
# City                     0
# Postal Code              0
# Order Date               0
# Ship Date                0
# Profit                   0
# Quantity ordered new     0
# Sales                    0
# Order ID                 0
# dtype: int64

# %%
t1.describe()
# Out:
#              Row ID     Discount   Unit Price  Shipping Cost  Customer ID  \
# count   9426.000000  9426.000000  9426.000000    9426.000000  9426.000000
# mean   20241.015277     0.049628    88.303686      12.795142  1738.422236
# min        2.000000     0.000000     0.990000       0.490000     2.000000
# 25%    19330.250000     0.020000     6.480000       3.192500   898.000000
# 50%    21686.500000     0.050000    20.990000       6.050000  1750.000000
# 75%    24042.750000     0.080000    85.990000      13.990000  2578.750000
# max    26399.000000     0.250000  6783.020000     164.730000  3403.000000
# std     6101.890965     0.031798   281.540982      17.181203   979.167197
#
#        Product Base Margin   Postal Code                     Order Date  \
# count          9354.000000   9426.000000                           9426
# mean              0.512189  52446.327286  2012-03-05 18:33:59.465308672
# min               0.350000   1001.000000            2010-01-01 00:00:00
# ...

# %%
t1['Product Base Margin'].fillna(t1['Product Base Margin'].mean())
# Out:
# 0       0.36
# 1       0.54
# 2       0.37
# 3       0.56
# 4       0.59
#         ...
# 9421    0.40
# 9422    0.54
# 9423    0.71
# 9424    0.65
# 9425    0.38
# Name: Product Base Margin, Length: 9426, dtype: float64

# %%
t1['Order Priority'].value_counts()
# Out:
# Order Priority
# High             1970
# Low              1926
# Not Specified    1881
# Medium           1844
# Critical         1804
# Critical            1
# Name: count, dtype: int64

# %% [markdown]
# ## Analysis on the basis of Order Priority

# %%
t1['Order Priority'].unique()
# Out:
# array(['Not Specified', 'High', 'Medium', 'Low', 'Critical', 'Critical '],
#       dtype=object)

# %%
t1['Order Priority']=t1['Order Priority'].replace("Critical ","Critical")

# %%
plt.figure(figsize=(8,6))
count= sns.countplot(data = t1, x = "Order Priority"  , hue = "Order Priority", palette={'Not Specified':'#944121', 'High':'#29c4a0', 'Medium':'#1d4f85', 'Low':'#83d419', 'Critical' :'#f0bc13'})
count.bar_label(count.containers[0])
count.bar_label(count.containers[1])
count.bar_label(count.containers[2])
count.bar_label(count.containers[3])
count.bar_label(count.containers[4])
plt.title("Analysis on the basis of Order Priority", fontsize=20, fontweight='bold', pad=20)
plt.savefig("Analysis on the basis of Order Priority.jpg")
plt.show()

# %% [markdown]
# ## Distribution on the basis of Ship Mode

# %%
t1['Ship Mode'].unique()
# Out:
# array(['Regular Air', 'Express Air', 'Delivery Truck'], dtype=object)

# %%
t1['Ship Mode'].value_counts()
# Out:
# Ship Mode
# Regular Air       7036
# Delivery Truck    1283
# Express Air       1107
# Name: count, dtype: int64

# %%
plt.figure(figsize=(7,5))
count= sns.countplot(data = t1, x = "Ship Mode"  , hue = "Ship Mode", palette={'Regular Air':'#72996e','Express Air':'#14addb', 'Delivery Truck':'#f0bc13'})
count.bar_label(count.containers[0])
count.bar_label(count.containers[1])
count.bar_label(count.containers[2])
plt.title("Distribution on the basis of Ship Mode", fontsize=20, fontweight='bold', pad=20)
plt.savefig("Distribution on the basis of Ship Mode.jpg")
plt.show()

# %%
x = t1['Ship Mode'].value_counts().index
x
# Out:
# Index(['Regular Air', 'Delivery Truck', 'Express Air'], dtype='object', name='Ship Mode')

# %%
y = t1['Ship Mode'].value_counts().values
y
# Out:
# array([7036, 1283, 1107], dtype=int64)

# %%
plt.figure(figsize=(7,6))
lbs = ['Regular Air', 'Delivery Truck', 'Express Air']
plt.pie(y, labels = lbs,autopct = "%0.2f%%",  wedgeprops={'linewidth': .5, 'edgecolor': 'white'},startangle=60)
plt.title("Analysis on the basis of Ship Mode", fontsize=20, fontweight='bold', pad=20 )
plt.legend(loc=2)
plt.savefig("Analysis on the basis of ShipMode.jpg")
plt.show()

# %% [markdown]
# ## Analysis on the basis of Order Product Category

# %%
t1['Product Category'].unique()
# Out:
# array(['Office Supplies', 'Technology', 'Furniture'], dtype=object)

# %%
t1['Product Category'].value_counts()
# Out:
# Product Category
# Office Supplies    5181
# Technology         2312
# Furniture          1933
# Name: count, dtype: int64

# %%
x1 = t1['Product Category'].value_counts().index
x1
# Out:
# Index(['Office Supplies', 'Technology', 'Furniture'], dtype='object', name='Product Category')

# %%
y1 = t1['Product Category'].value_counts().values
y1
# Out:
# array([5181, 2312, 1933], dtype=int64)

# %%
plt.figure(figsize=(7,5))
color = [ '#f0bc13', '#88de18', '#1d4f85']
plt.pie(y1, labels=x1, startangle=90, autopct='%0.2f%%', colors = color, wedgeprops={'linewidth': .5, 'edgecolor': 'white'})
plt.legend(loc=3)
plt.title("Analysis on the basis of Product Category", fontsize=20, fontweight='bold', pad=20 )
plt.savefig("Analysis on the basis of Product Category.jpg")
plt.show()

# %%
plt.figure(figsize=(7,5))
count= sns.countplot(data = t1, x = "Product Category"  , hue = "Product Category", palette={'Technology':'#944121', 'Office Supplies':'#29c4a0', 'Furniture':'#1d4f85'})
count.bar_label(count.containers[0])
count.bar_label(count.containers[1])
count.bar_label(count.containers[2])
plt.title("Analysis on the basis of Product Categories", fontsize=20, fontweight='bold', pad=20 )
plt.savefig("Analysis on the basis of Product Categories.jpg")
plt.show()

# %% [markdown]
# ## Analysis on the basis of Product Category And Ship Mode

# %%
plt.figure(figsize=(9,5))
count= sns.countplot(data = t1, x = "Ship Mode"  , hue = "Product Category")
# count.bar_label(count.containers[0])
# count.bar_label(count.containers[1])
# count.bar_label(count.containers[2])
plt.title("Analysis on the basis of Product Category & Ship Mode", fontsize=20, fontweight='bold', pad=20 )
plt.savefig("Analysis on the basis of Product Category And Ship Mode.jpg")
plt.show()

# %% [markdown]
# ## Analysis on the basis of Customer Segment

# %%
t1['Customer Segment'].unique()
# Out:
# array(['Corporate', 'Home Office', 'Small Business', 'Consumer'],
#       dtype=object)

# %%
t1['Customer Segment'].value_counts()
# Out:
# Customer Segment
# Corporate         3375
# Home Office       2316
# Consumer          1894
# Small Business    1841
# Name: count, dtype: int64

# %%
plt.figure(figsize=(7,5))
count = sns.countplot(data = t1, x = 'Customer Segment', hue = "Customer Segment", palette={'Corporate':'#275f8c', 'Home Office':'#fc970a', 'Small Business':'#2e8f1d','Consumer':'#fc1a0a'})
count.bar_label(count.containers[0])
count.bar_label(count.containers[1])
count.bar_label(count.containers[2])
count.bar_label(count.containers[3])
plt.title("Analysis on the basis of Customer Segment", fontsize=20, fontweight='bold', pad=20 )
plt.savefig("Analysis on the basis of Customer Segment.jpg")
plt.show()

# %% [markdown]
# ## Analysis on the basis of City

# %%
# t1['City'].unique()

# %%
# t1['City'].value_counts()

# %%
# x2 = t1["City"].value_counts().index
# x2

# %%
# y2 = t1["City"].value_counts().values
# y2

# %%
# plt.figure(figsize=(7,5))
# # color = [ '#f0bc13', '#88de18', '#1d4f85']
# plt.pie(y2, wedgeprops={'linewidth': .5, 'edgecolor': 'white'})
# # plt.legend(loc=3)
# # plt.title("Analysis on the basis of Product Category", fontsize=20, fontweight='bold', pad=20 )
# # plt.savefig("Analysis on the basis of Product Category.jpg")
# plt.show()

# %% [markdown]
# ## Analysis on the basis of Product Category & Sub-Category

# %%
t1['Product Sub-Category'].unique()
# Out:
# array(['Labels', 'Pens & Art Supplies', 'Paper',
#        'Scissors, Rulers and Trimmers', 'Telephones and Communication',
#        'Office Machines', 'Chairs & Chairmats', 'Appliances', 'Bookcases',
#        'Tables', 'Envelopes', 'Office Furnishings', 'Rubber Bands',
#        'Binders and Binder Accessories', 'Storage & Organization',
#        'Computer Peripherals', 'Copiers and Fax'], dtype=object)

# %%
t1['Product Sub-Category'].value_counts()
# Out:
# Product Sub-Category
# Paper                             1379
# Binders and Binder Accessories    1028
# Telephones and Communication       992
# Office Furnishings                 883
# Computer Peripherals               846
# Pens & Art Supplies                721
# Storage & Organization             610
# Appliances                         492
# Chairs & Chairmats                 440
# Tables                             404
# Office Machines                    376
# Labels                             329
# Envelopes                          272
# Bookcases                          206
# Rubber Bands                       195
# Scissors, Rulers and Trimmers      155
# Copiers and Fax                     98
# Name: count, dtype: int64

# %% [markdown]
# ## Office Supplies

# %%
plt.figure(figsize=(11,7))
count= sns.countplot(data = t1[t1['Product Category']=='Office Supplies'],  x = "Product Category"  , hue = "Product Sub-Category")
count.bar_label(count.containers[0])
count.bar_label(count.containers[1])
count.bar_label(count.containers[2])
count.bar_label(count.containers[3])
count.bar_label(count.containers[4])
count.bar_label(count.containers[5])
count.bar_label(count.containers[6])
count.bar_label(count.containers[7])
count.bar_label(count.containers[8])
plt.legend(loc=1, fontsize=7)
plt.title("Analysis on the basis of Product Category & Sub-Category", fontsize=20, fontweight='bold', pad=20 )
plt.savefig("Analysis on the basis of Product Category And Product Sub-Category.jpg")
plt.show()

# %% [markdown]
# ## Technology

# %%
plt.figure(figsize=(5,6))
count= sns.countplot(data = t1[t1['Product Category']=='Technology'],  x = "Product Category"  , hue = "Product Sub-Category")
count.bar_label(count.containers[0])
count.bar_label(count.containers[1])
count.bar_label(count.containers[2])
count.bar_label(count.containers[3])
plt.legend(loc=1, fontsize=8)
plt.title("Analysis on the basis of Product Category & Sub-Category", fontsize=20, fontweight='bold', pad=20 )
plt.savefig("Analysis on the basis of Product Category And Product Sub-Category.jpg")
plt.show()

# %% [markdown]
# ## Furniture

# %%
plt.figure(figsize=(5,6))
count= sns.countplot(data = t1[t1['Product Category']=='Furniture'],  x = "Product Category"  , hue = "Product Sub-Category")
count.bar_label(count.containers[0])
count.bar_label(count.containers[1])
count.bar_label(count.containers[2])
count.bar_label(count.containers[3])
plt.legend(loc=2, fontsize=11)
plt.title("Analysis on the basis of Product Category & Sub-Category", fontsize=20, fontweight='bold', pad=20 )
plt.savefig("Analysis on the basis of Product Category And Product Sub-Category.jpg")
plt.show()

# %% [markdown]
# ## Analysis on the basis of Order Year

# %%
t1['Order year'] = t1['Order Date'].dt.year

# %%
t1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9426 entries, 0 to 9425
# Data columns (total 25 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Row ID                9426 non-null   int64
#  1   Order Priority        9426 non-null   object
#  2   Discount              9426 non-null   float64
#  3   Unit Price            9426 non-null   float64
#  4   Shipping Cost         9426 non-null   float64
#  5   Customer ID           9426 non-null   int64
#  6   Customer Name         9426 non-null   object
#  7   Ship Mode             9426 non-null   object
#  8   Customer Segment      9426 non-null   object
#  9   Product Category      9426 non-null   object
#  10  Product Sub-Category  9426 non-null   object
#  11  Product Container     9426 non-null   object
#  12  Product Name          9426 non-null   object
#  13  Product Base Margin   9354 non-null   float64
#  14  Region                9426 non-null   object
# ...

# %%
t1['Order year'].value_counts()
# Out:
# Order year
# 2013    3054
# 2012    2241
# 2011    2179
# 2010    1952
# Name: count, dtype: int64

# %%
plt.figure(figsize=(7,5))
count = sns.countplot(data = t1, x = 'Order year', hue = "Order year")
count.bar_label(count.containers[0])
count.bar_label(count.containers[1])
count.bar_label(count.containers[2])
count.bar_label(count.containers[3])
plt.title("Analysis on the basis of Order Year", fontsize=20, fontweight='bold', pad=20 )
plt.savefig("Analysis on the basis of Order Year.jpg")
plt.show()

# %% [markdown]
# ## Analysis on the basis of Profit

# %%
plt.figure(figsize=(6,5))
sns.barplot(data = t1, x = "Product Category", y = "Profit", estimator = 'sum', hue = "Product Category", palette={'Technology':'#fcad0f', 'Office Supplies':'#29c4a0', 'Furniture':'#1d4f85'})
plt.title("Analysis on the basis of Profit", fontsize=20, fontweight='bold', pad=20 )
plt.savefig("Analysis on the basis of Profit.jpg")
plt.show()

# %% [markdown]
# ## Analysis on the basis of State or Province

# %%
t1['State or Province'].value_counts()[:5]
# Out:
# State or Province
# California    1021
# Texas          646
# Illinois       584
# New York       574
# Florida        522
# Name: count, dtype: int64

# %%
t1['State or Province'].value_counts()
# Out:
# State or Province
# California              1021
# Texas                    646
# Illinois                 584
# New York                 574
# Florida                  522
# Ohio                     396
# Washington               327
# Michigan                 327
# Pennsylvania             271
# North Carolina           251
# Indiana                  241
# Minnesota                239
# Massachusetts            222
# Georgia                  214
# Virginia                 198
# Maryland                 178
# Colorado                 177
# New Jersey               177
# Wisconsin                169
# Oregon                   168
# Tennessee                166
# Missouri                 161
# Iowa                     156
# Utah                     146
# Arizona                  134
# Kansas                   133
# Maine                    128
# Alabama                  125
# Arkansas                 123
# Idaho                    114
# South Carolina           105
# ...

# %%
t1['State or Province'].unique()
# Out:
# array(['Illinois', 'Washington', 'California', 'Massachusetts',
#        'New Hampshire', 'New Jersey', 'Rhode Island', 'Minnesota',
#        'New York', 'Montana', 'Nebraska', 'Oregon', 'Texas', 'Virginia',
#        'Vermont', 'Maine', 'Ohio', 'Louisiana', 'Kansas', 'Connecticut',
#        'Utah', 'Pennsylvania', 'Tennessee', 'Colorado', 'Michigan',
#        'Arizona', 'Oklahoma', 'Missouri', 'North Carolina', 'Iowa',
#        'Florida', 'New Mexico', 'Georgia', 'Maryland', 'Nevada',
#        'Mississippi', 'Indiana', 'Kentucky', 'West Virginia', 'Arkansas',
#        'South Carolina', 'District of Columbia', 'Idaho', 'Delaware',
#        'Alabama', 'Wyoming', 'Wisconsin', 'South Dakota', 'North Dakota'],
#       dtype=object)

# %%
plt.figure(figsize=(90,30))
count = sns.countplot(data = t1, x = 'State or Province', hue = "State or Province")
# count.bar_label(count.containers[0])
# count.bar_label(count.containers[1])
# count.bar_label(count.containers[2])
# count.bar_label(count.containers[3])
plt.title("Analysis on the basis of State or Province", fontsize=90, fontweight='bold', pad=20 )
plt.savefig("Analysis on the basis of State or Province.jpg")
plt.show()

# %% [markdown]
# ## Analysis on the basis of Top 5 State or Provinces

# %%
top_Five_state = t1['State or Province'].value_counts().head(5).index

# %%
filtered_data = t1[t1['State or Province'].isin(top_Five_state)]

# %%
plt.figure(figsize=(8,6))
count = sns.countplot(data = filtered_data, x = 'State or Province', hue = "State or Province")
# count.bar_label(count.containers[0])
# count.bar_label(count.containers[1])
# count.bar_label(count.containers[2])
# count.bar_label(count.containers[3])
plt.title("Analysis on the basis of Top 5 State or Provinces", fontsize=20, fontweight='bold', pad=20 )
plt.savefig("Analysis on the basis of Top 5 State or Provinces.jpg")
plt.show()

# %% [markdown]
# ## Analysis on the basis of Box Packaging

# %%
t1['Product Container'].unique()
# Out:
# array(['Small Box', 'Wrap Bag', 'Small Pack', 'Jumbo Drum', 'Jumbo Box',
#        'Medium Box', 'Large Box'], dtype=object)

# %%
t1['Product Container'].value_counts()
# Out:
# Product Container
# Small Box     4887
# Wrap Bag      1312
# Small Pack    1067
# Jumbo Drum     703
# Jumbo Box      590
# Large Box      457
# Medium Box     410
# Name: count, dtype: int64

# %%
x3 = t1['Product Container'].value_counts().index

# %%
y3 = t1['Product Container'].value_counts().values

# %%
plt.figure(figsize=(9,8))
plt.pie(y3, labels = x3, autopct = "%0.2f%%", wedgeprops={'linewidth': .5, 'edgecolor': 'white'},startangle=60)
plt.legend(loc=2, fontsize=9)
plt.title("Analysis on the basis of Box Packaging", fontsize=20, fontweight='bold', pad=20 )
plt.savefig("Analysis on the basis of Box Packaging.jpg")
plt.show()

# %%
plt.figure(figsize=(10,5))
count= sns.countplot(data = t1, x = "Product Container"  , hue = "Product Container")
# count.bar_label(count.containers[0])
# count.bar_label(count.containers[1])
# count.bar_label(count.containers[2])
plt.title("Analysis on the basis of Boxes Packaging", fontsize=20, fontweight='bold', pad=20)
plt.savefig("Analysis on the basis of Boxes Packaging.jpg")
plt.show()

# %% [markdown]
# ## Analysis on the basis of Product Base Margin

# %%
plt.figure(figsize=(8,5))
sns.barplot(data = t1, x = "Product Category", y = "Product Base Margin", estimator = 'sum', hue = "Product Category", palette={'Technology':'#fcb02b', 'Office Supplies':'#ab66b0', 'Furniture':'#5b8a87'})
plt.title("Analysis on the basis of Product Base Margin", fontsize=20, fontweight='bold', pad=20 )
plt.savefig("Analysis on the basis of Product Base Margin.jpg")
plt.show()
